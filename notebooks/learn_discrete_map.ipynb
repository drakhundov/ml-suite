# %%
! pip install numpy
! pip install scikit-learn

# %%
import os, sys
sys.path.insert(0, os.path.join(os.getcwd(), "../src"))

# %%
from mlsuite.clf import DiscreteMAP
from mlsuite.learn import IrisLearner

# %%
model = DiscreteMAP()
learner = IrisLearner(model)

# %%
learner.fit()
learner.test()
# Out:
# TestStats(TP=np.int64(10), TN=np.int64(20), FP=np.int64(0), FN=np.int64(0), accuracy=np.float64(1.0), recall=np.float64(1.0), precision=np.float64(1.0), F1=np.float64(2.0), MSE=0.0)
